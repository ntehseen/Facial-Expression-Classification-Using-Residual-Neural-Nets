# %% [markdown]
# <h1>Facial Expression Classification Using Residual Neural Nets </h1>

# %% [markdown]
# ## Introduction
# This projects is to create a Deep learning model baswd on Convolutional Neyral Networks and Residual Blocks to predict Facial Expressions or Emotions.
#
# Facial Expression serves as a basis for Emotional Artificial Intelligence applications, such as detecting customer's emotional responses to Advertisements and Driver Monitoring Systems.

# %% [markdown]
# <h1> Project Structure</h1> <br>
#
# Facial Expression Classification Using Residual Neural Nets is divided into following tasks:
#
# - Project Overview/Understand the problem statement and business case
#
# - Import Libraries/datasets and perform preliminary data processing
#
# - Perform Image Visualization
#
# - Perform Image Augmentation, normalization and splitting
#
# - Build and Train Residual Neural Network Model
#
# - Assess the Performance of the Trained Model

# %% [markdown]
# # STEP 1 #
#  IMPORT LIBRARIES AND DATASETS

# %%
#!pip install tensorflow==2.0
# !pip install opencv-python

# %%
import tensorflow as tf
tf.version.VERSION
# Out:
# 2024-03-09 05:22:40.292368: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# '2.15.0'

# %%
import cv2
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import os
import PIL
from tensorflow.keras import layers
import tensorflow as tf
import pickle
from tensorflow.python.keras import *
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import layers, optimizers
from tensorflow.keras.applications import DenseNet121
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.layers import *
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.initializers import glorot_uniform
from tensorflow.keras.utils import plot_model
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping, ModelCheckpoint, LearningRateScheduler
from IPython.display import display
from tensorflow.keras import backend as K
#from jupyterthemes import jtplot
#jtplot.style(theme='monokai', context='notebook', ticks=True, grid=False)
# setting the style of the notebook to be monokai theme
# this line of code is important to ensure that we are able to see the x and y axes clearly
# If you don't run this code line, you will notice that the xlabel and ylabel on any plot is black on black and it will be hard to see them.

# %%
# read the csv files
emotion_df = pd.read_csv('emotion.csv')

# %%
emotion_df
# Out:
#        emotion                                             pixels
# 0            0  70 80 82 72 58 58 60 63 54 58 60 48 89 115 121...
# 1            0  151 150 147 155 148 133 111 140 170 174 182 15...
# 2            2  24 32 36 30 32 23 19 20 30 41 21 22 32 34 21 1...
# 3            2  20 17 19 21 25 38 42 42 46 54 56 62 63 66 82 1...
# 4            3  77 78 79 79 78 75 60 55 47 48 58 73 77 79 57 5...
# ...        ...                                                ...
# 24563        3  0 39 81 80 104 97 51 64 68 46 41 67 53 68 70 5...
# 24564        0  181 177 176 156 178 144 136 132 122 107 131 16...
# 24565        3  178 174 172 173 181 188 191 194 196 199 200 20...
# 24566        0  17 17 16 23 28 22 19 17 25 26 20 24 31 19 27 9...
# 24567        3  30 28 28 29 31 30 42 68 79 81 77 67 67 71 63 6...
#
# [24568 rows x 2 columns]

# %%
emotion_df['emotion'][:]
# Out:
# 0        0
# 1        0
# 2        2
# 3        2
# 4        3
#         ..
# 24563    3
# 24564    0
# 24565    3
# 24566    0
# 24567    3
# Name: emotion, Length: 24568, dtype: int64

# %%
emotion_df.emotion.value_counts()
# Out:
# emotion
# 3    8989
# 2    6077
# 0    4953
# 4    4002
# 1     547
# Name: count, dtype: int64

# %%
emotion_df['pixels'] = emotion_df[' pixels'] # String format

# %%
emotion_df['pixels'][2] # String format
# Out:
# '24 32 36 30 32 23 19 20 30 41 21 22 32 34 21 19 43 52 13 26 40 59 65 12 20 63 99 98 98 111 75 62 41 73 118 140 192 186 187 188 190 190 187 182 176 173 172 173 25 34 29 35 29 26 20 23 19 31 22 21 20 31 26 17 34 75 37 18 38 80 85 25 38 26 34 97 94 76 86 95 70 39 98 129 185 188 188 189 190 190 188 182 176 173 172 173 26 29 25 35 25 30 20 21 16 28 34 26 15 17 19 22 29 62 64 47 45 76 76 78 65 82 12 14 56 56 72 74 66 65 86 129 172 190 187 189 190 190 187 182 177 172 172 174 26 33 32 31 25 33 26 21 16 16 37 27 14 15 12 17 31 38 40 58 73 59 35 82 68 72 43 22 33 52 51 66 71 57 71 121 160 191 188 189 190 190 187 184 178 173 173 174 29 40 29 29 32 32 28 26 19 13 23 34 17 18 14 15 26 25 21 40 82 44 29 34 36 32 36 59 55 38 46 64 71 62 60 107 137 191 189 190 190 190 188 184 178 175 173 175 33 39 25 33 37 33 25 30 20 18 18 23 20 22 20 17 33 20 18 25 37 31 22 29 28 24 29 38 67 38 35 75 68 66 58 89 110 179 191 189 189 190 187 184 179 175 173 174 32 41 32 31 39 33 26 34 27 23 28 30 21 24 29 22 26 23 21 22 33 28 28 26 28 23 27 21 61 53 24 72 78 64 54 84 94 155 195 189 191 190 188 184 179 174 172 173 28 46 40 29 42 34 31 39 37 30 33 33 28 23 30 31 24 19 17 18 27 25 27 23 25 24 23 13 40 69 29 45 74 74 59 88 88 145 196 188 191 191 188 183 178 174 172 174 27 44 42 35 42 34 39 40 41 37 33 33 34 31 32 35 32 19 19 18 16 17 22 21 23 25 22 14 30 74 36 32 62 75 59 89 94 139 194 188 191 191 187 184 179 174 173 174 28 38 38 42 41 36 51 44 37 40 35 33 29 38 38 43 39 28 23 19 22 24 26 27 26 29 21 17 37 75 31 32 49 55 57 102 108 138 193 189 191 192 189 184 180 176 174 174 29 33 30 34 41 39 46 45 37 38 38 34 28 39 41 44 36 37 28 29 32 34 35 34 33 33 27 23 39 72 28 22 44 70 82 127 100 137 194 189 190 189 188 185 181 176 174 176 29 32 28 24 40 35 35 30 30 31 38 29 31 37 30 34 30 41 52 57 58 56 53 45 50 40 46 24 30 60 27 64 120 130 141 139 85 149 194 187 189 188 187 185 181 177 175 176 34 24 33 27 26 27 27 21 24 28 34 27 33 30 23 26 27 52 91 125 125 119 100 89 88 84 66 24 48 57 89 137 155 159 175 155 105 173 193 189 189 189 187 185 181 177 175 176 33 74 146 130 75 24 23 20 20 23 26 24 27 24 24 31 60 118 156 158 156 155 141 135 131 108 42 68 73 97 140 146 164 178 186 191 156 185 189 189 188 188 186 184 180 177 175 176 45 121 121 162 155 61 17 22 21 23 22 21 21 24 29 62 127 165 170 163 166 159 144 128 103 53 67 99 90 129 148 153 175 195 201 180 174 188 187 188 188 187 186 184 180 177 176 176 64 105 116 165 150 143 45 17 19 23 23 22 23 25 52 122 166 171 172 174 169 160 152 128 91 97 124 119 123 144 151 157 179 177 143 154 184 187 188 189 189 187 186 183 180 177 176 176 125 93 150 159 133 143 106 33 49 27 24 25 23 44 120 166 170 165 159 142 132 120 117 119 129 131 128 132 135 142 146 158 144 94 131 185 185 186 187 188 189 187 185 183 179 176 175 176 201 82 161 117 85 143 158 109 119 67 21 39 86 132 168 173 171 167 161 148 134 123 102 89 100 102 97 108 124 131 152 118 75 138 131 170 185 186 187 188 189 187 185 183 178 175 175 175 225 80 130 122 84 146 145 162 159 129 31 94 168 172 170 170 167 162 143 117 112 77 50 47 65 100 127 135 129 137 157 56 73 168 181 180 185 187 188 189 189 187 184 181 178 174 173 175 217 80 78 165 127 109 119 169 173 163 108 138 172 168 172 171 165 158 140 101 65 43 44 56 38 95 141 160 146 166 142 62 116 171 198 180 185 186 188 188 187 186 183 181 177 174 173 175 194 64 36 127 178 168 113 132 172 166 153 158 170 170 171 173 171 168 165 161 139 96 72 69 53 111 163 170 155 163 187 143 162 205 204 180 186 187 188 188 187 185 184 181 177 174 173 175 144 55 54 51 146 177 158 154 173 169 160 165 168 161 145 136 164 172 167 153 137 132 117 90 85 134 168 176 162 160 212 197 188 208 203 182 188 187 189 189 187 186 184 181 177 174 173 175 127 79 91 61 47 157 160 166 161 164 160 154 148 153 146 105 131 154 146 145 128 108 118 104 114 127 156 166 156 163 207 190 185 207 194 181 183 185 180 180 184 181 183 180 176 174 172 174 136 102 122 138 60 73 130 139 138 153 137 142 122 135 140 114 89 144 117 108 116 110 110 103 97 107 142 145 139 151 202 157 159 189  ...

# %%
# function to convert pixel values in string format to array format
def string2array(x):
  return np.array(x.split(' ')).reshape(48, 48, 1).astype('float32')

# %%
emotion_df['pixels'] = emotion_df['pixels'].apply(lambda x: string2array(x))

# %%
emotion_df['pixels'][2].shape
# Out:
# (48, 48, 1)

# %%
emotion_df['pixels'][2]
# Out:
# array([[[ 24.],
#         [ 32.],
#         [ 36.],
#         ...,
#         [173.],
#         [172.],
#         [173.]],
#
#        [[ 25.],
#         [ 34.],
#         [ 29.],
#         ...,
#         [173.],
#         [172.],
#         [173.]],
#
#        [[ 26.],
#         [ 29.],
#         [ 25.],
#         ...,
#         [172.],
#         [172.],
#         [174.]],
#
#        ...,
#
#        [[159.],
#         [185.],
#         [157.],
#         ...,
#         [157.],
#         [156.],
#         [153.]],
#
#        [[136.],
#         [157.],
#         [187.],
#         ...,
#         [152.],
#         [152.],
#         [150.]],
#
#        [[145.],
#         [130.],
#         [161.],
#         ...,
#         [142.],
#         [143.],
#         [142.]]], dtype=float32)

# %%
# checking for the presence of null values in the data frame
emotion_df.isnull().sum()
# Out:
# emotion    0
#  pixels    0
# pixels     0
# dtype: int64

# %%
label_to_text = {0:'anger', 1:'disgust', 2:'sad', 3:'happiness', 4: 'surprise'}

# %% [markdown]
# - Visualize the first image in the dataframe and make sure that the image is not distorted by reshaping operation

# %%
plt.imshow(emotion_df['pixels'][3].squeeze(), cmap = 'gray')

# %% [markdown]
# # STEP 2: #
#  PERFORM DATA VISUALIZATION

# %%
emotions = [0,1,2,3,4]

for i in emotions:
  data = emotion_df[emotion_df['emotion'] == i][:1]
  img = data['pixels'].item()
  img = img.reshape(48,48)
  plt.figure()
  plt.title(label_to_text[i])
  plt.imshow(img, cmap= 'gray')

# %% [markdown]
# - Plot barplot showing how many samples are present per emotion

# %%
plt.figure(figsize = (10,10))
sns.barplot(x = emotion_df.emotion.value_counts().index, y = emotion_df.emotion.value_counts())
plt.title('Number of Images per Emotions')
# Out:
# /Users/deathslayer/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/deathslayer/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/deathslayer/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# Text(0.5, 1.0, 'Number of Images per Emotions')

# %% [markdown]
# # STEP 3:
#  PERFORM DATA AUGMENTATION

# %%
emotion_df['pixels'][0]
# Out:
# array([[[ 70.],
#         [ 80.],
#         [ 82.],
#         ...,
#         [ 52.],
#         [ 43.],
#         [ 41.]],
#
#        [[ 65.],
#         [ 61.],
#         [ 58.],
#         ...,
#         [ 56.],
#         [ 52.],
#         [ 44.]],
#
#        [[ 50.],
#         [ 43.],
#         [ 54.],
#         ...,
#         [ 49.],
#         [ 56.],
#         [ 47.]],
#
#        ...,
#
#        [[ 91.],
#         [ 65.],
#         [ 42.],
#         ...,
#         [ 72.],
#         [ 56.],
#         [ 43.]],
#
#        [[ 77.],
#         [ 82.],
#         [ 79.],
#         ...,
#         [105.],
#         [ 70.],
#         [ 46.]],
#
#        [[ 77.],
#         [ 72.],
#         [ 84.],
#         ...,
#         [106.],
#         [109.],
#         [ 82.]]], dtype=float32)

# %%
emotion_df.emotion[2]
# Out:
# 2

# %%
X = emotion_df['pixels']
X.shape
# Out:
# (24568,)

# %%
# split the dataframe to features and labels
# from keras.utils import to_categorical

X = emotion_df['pixels']
# y = to_categorical(emotion_df['emotion'])
y = pd.get_dummies(emotion_df['emotion'])

X = np.stack(X, axis = 0)
X = X.reshape(24568, 48, 48, 1)

print(X.shape, y.shape)
# Out:
# (24568, 48, 48, 1) (24568, 5)

# %%
X.shape
# Out:
# (24568, 48, 48, 1)

# %%
y
# Out:
#            0      1      2      3      4
# 0       True  False  False  False  False
# 1       True  False  False  False  False
# 2      False  False   True  False  False
# 3      False  False   True  False  False
# 4      False  False  False   True  False
# ...      ...    ...    ...    ...    ...
# 24563  False  False  False   True  False
# 24564   True  False  False  False  False
# 24565  False  False  False   True  False
# 24566   True  False  False  False  False
# 24567  False  False  False   True  False
#
# [24568 rows x 5 columns]

# %%
X
# Out:
# array([[[[ 70.],
#          [ 80.],
#          [ 82.],
#          ...,
#          [ 52.],
#          [ 43.],
#          [ 41.]],
#
#         [[ 65.],
#          [ 61.],
#          [ 58.],
#          ...,
#          [ 56.],
#          [ 52.],
#          [ 44.]],
#
#         [[ 50.],
#          [ 43.],
#          [ 54.],
#          ...,
#          [ 49.],
#          [ 56.],
#          [ 47.]],
#
#         ...,
#
#         [[ 91.],
#          [ 65.],
#          [ 42.],
#          ...,
#          [ 72.],
#          [ 56.],
#          [ 43.]],
#
#         [[ 77.],
#          [ 82.],
#          [ 79.],
#          ...,
#          [105.],
#          [ 70.],
#          [ 46.]],
#
#         [[ 77.],
#          [ 72.],
#          [ 84.],
#          ...,
#          [106.],
#          [109.],
#          [ 82.]]],
#
#
#        [[[151.],
#          [150.],
#          [147.],
#          ...,
#          [129.],
#          [140.],
#          [120.]],
#
#         [[151.],
#          [149.],
#          [149.],
#          ...,
#          [122.],
#          [141.],
#          [137.]],
#
#         [[151.],
#          [151.],
#          [156.],
#          ...,
#          [109.],
#          [123.],
#          [146.]],
#
#         ...,
#
#         [[188.],
#          [188.],
#          [121.],
#          ...,
#          [185.],
#          [185.],
#          [186.]],
#
#         [[188.],
#          [187.],
#          [196.],
#          ...,
#          [186.],
#          [182.],
#          [187.]],
#
#         [[186.],
#          [184.],
#          [185.],
#          ...,
#          [193.],
#          [183.],
#          [184.]]],
#
#
#        [[[ 24.],
#          [ 32.],
#          [ 36.],
#          ...,
#          [173.],
#          [172.],
#          [173.]],
#
#         [[ 25.],
#          [ 34.],
#          [ 29.],
#          ...,
#          [173.],
#          [172.],
#          [173.]],
#
#         [[ 26.],
#          [ 29.],
#          [ 25.],
#          ...,
#          [172.],
#          [172.],
#          [174.]],
#
#         ...,
#
#         [[159.],
#          [185.],
#          [157.],
#          ...,
#          [157.],
#          [156.],
#          [153.]],
#
#         [[136.],
#          [157.],
#          [187.],
#          ...,
#          [152.],
#          [152.],
#          [150.]],
#
#         [[145.],
#          [130.],
#          [161.],
#          ...,
#          [142.],
#          [143.],
#          [142.]]],
#
#
#        ...,
#
#
#        [[[178.],
#          [174.],
#          [172.],
#          ...,
#          [ 78.],
#          [ 41.],
#          [ 57.]],
#
#         [[181.],
#          [178.],
#          [178.],
#          ...,
#          [126.],
#          [ 63.],
#          [ 64.]],
#
#         [[181.],
#          [176.],
#          [176.],
#          ...,
#          [177.],
#          [145.],
#          [ 82.]],
#
#         ...,
#
#         [[193.],
#          [191.],
#          [187.],
#          ...,
#          [  1.],
#          [  1.],
#          [  0.]],
#
#         [[193.],
#          [192.],
#          [191.],
#          ...,
#          [  0.],
#          [  0.],
#          [  0.]],
#
#         [[194.],
#          [191.],
#          [192.],
#          ...,
#          [  0.],
#          [  0.],
#          [  0.]]],
#
#
#        [[[ 17.],
#          [ 17.],
#          [ 16.],
#          ...,
#          [ 83.],
#          [114.],
#          [245.]],
#
#         [[ 18.],
#          [ 17.],
#          [ 16.],
#          ...,
#          [104.],
#          [136.],
#          [253.]],
#
#         [[ 19.],
#          [ 16.],
#          [ 17.],
#          ...,
#          [128.],
#          [152.],
#          [255.]],
#
#         ...,
#
#         [[  4.],
#          [ 21.],
#          [ 46.],
#          ...,
#          [186.],
#          [180.],
#          [187.]],
#
#         [[  5.],
#          [ 17.],
#          [ 41.],
#          ...,
#          [177.],
#          [172.],
#          [176.]],
#
#         [[ 20.],
#          [ 15.],
#          [ 22.],
#          ...,
#          [154.],
#          [133.],
#          [113.]]],
#
#
#        [[[ 30.],
#          [ 28.],
#          [ 28.],
#          ...,
#          [ 60.],
#          [ 50.],
#          [ 44.]],
#
#         [[ 30.],
#          [ 27.],
#          [ 28.],
#          ...,
#          [ 64.],
#          [ 52.],
#          [ 40.]],
#
#         [[ 31.],
#          [ 28.],
#          [ 30.],
#          ...,
#          [ 61.],
#          [ 54.],
#          [ 37.]],
#
#         ...,
#
#         [[104.],
#          [109.],
#          [110.],
#          ...,
#          [ 35.],
#          [ 30.],
#          [ 30.]],
#
#         [[102.],
#          [105.],
#          [108.],
#          ...,
#          [ 35.],
#          [ 31.],
#          [ 29.]],
#
#         [[ 93.],
#          [ 96.],
#          [100.],
#          ...,
#          [ 35.],
#          [ 30.],
#          [ 28.]]]], dtype=float32)

# %%
X = np.array(X)
y = np.array(y)

# %%
# spliting the dataframe in to train,test and validation data frames

from sklearn.model_selection import train_test_split

X_train, X_Test, y_train, y_Test = train_test_split(X,y,test_size = 0.1, shuffle = True)
X_val, X_Test, y_val, y_Test = train_test_split(X_Test,y_Test, test_size = 0.5, shuffle = True)

# %%
print(X_val.shape, y_val.shape)
# Out:
# (1228, 48, 48, 1) (1228, 5)

# %%
print(X_Test.shape, y_Test.shape)
# Out:
# (1229, 48, 48, 1) (1229, 5)

# %%
print(X_train.shape, y_train.shape)
# Out:
# (22111, 48, 48, 1) (22111, 5)

# %%
# image pre-processing

X_train = X_train/255
X_val   = X_val /255
X_Test  = X_Test/255

# %%
# train_datagen = ImageDataGenerator(
# rotation_range=15,
#     width_shift_range=0.1,
#     height_shift_range=0.1,
#     shear_range=0.1,
#     zoom_range=0.1,
#     horizontal_flip = True,
#     vertical_flip = True,
#     fill_mode = "nearest"
# )

# %% [markdown]
# # STEP 5: #
#  BUILD AND TRAIN DEEP LEARNING MODEL FOR FACIAL EXPRESSION CLASSIFICATION

# %%
def res_block(X, filter, stage):

  # Convolutional_block
  X_copy = X

  f1 , f2, f3 = filter

  # Main Path
  X = Conv2D(f1, (1,1),strides = (1,1), name ='res_'+str(stage)+'_conv_a', kernel_initializer= glorot_uniform(seed = 0))(X)
  X = MaxPool2D((2,2))(X)
  X = BatchNormalization(axis =3, name = 'bn_'+str(stage)+'_conv_a')(X)
  X = Activation('relu')(X)

  X = Conv2D(f2, kernel_size = (3,3), strides =(1,1), padding = 'same', name ='res_'+str(stage)+'_conv_b', kernel_initializer= glorot_uniform(seed = 0))(X)
  X = BatchNormalization(axis =3, name = 'bn_'+str(stage)+'_conv_b')(X)
  X = Activation('relu')(X)

  X = Conv2D(f3, kernel_size = (1,1), strides =(1,1),name ='res_'+str(stage)+'_conv_c', kernel_initializer= glorot_uniform(seed = 0))(X)
  X = BatchNormalization(axis =3, name = 'bn_'+str(stage)+'_conv_c')(X)


  # Short path
  X_copy = Conv2D(f3, kernel_size = (1,1), strides =(1,1),name ='res_'+str(stage)+'_conv_copy', kernel_initializer= glorot_uniform(seed = 0))(X_copy)
  X_copy = MaxPool2D((2,2))(X_copy)
  X_copy = BatchNormalization(axis =3, name = 'bn_'+str(stage)+'_conv_copy')(X_copy)

  # ADD
  X = Add()([X,X_copy])
  X = Activation('relu')(X)

  # Identity Block 1
  X_copy = X


  # Main Path
  X = Conv2D(f1, (1,1),strides = (1,1), name ='res_'+str(stage)+'_identity_1_a', kernel_initializer= glorot_uniform(seed = 0))(X)
  X = BatchNormalization(axis =3, name = 'bn_'+str(stage)+'_identity_1_a')(X)
  X = Activation('relu')(X)

  X = Conv2D(f2, kernel_size = (3,3), strides =(1,1), padding = 'same', name ='res_'+str(stage)+'_identity_1_b', kernel_initializer= glorot_uniform(seed = 0))(X)
  X = BatchNormalization(axis =3, name = 'bn_'+str(stage)+'_identity_1_b')(X)
  X = Activation('relu')(X)

  X = Conv2D(f3, kernel_size = (1,1), strides =(1,1),name ='res_'+str(stage)+'_identity_1_c', kernel_initializer= glorot_uniform(seed = 0))(X)
  X = BatchNormalization(axis =3, name = 'bn_'+str(stage)+'_identity_1_c')(X)

  # ADD
  X = Add()([X,X_copy])
  X = Activation('relu')(X)

  # Identity Block 2
  X_copy = X


  # Main Path
  X = Conv2D(f1, (1,1),strides = (1,1), name ='res_'+str(stage)+'_identity_2_a', kernel_initializer= glorot_uniform(seed = 0))(X)
  X = BatchNormalization(axis =3, name = 'bn_'+str(stage)+'_identity_2_a')(X)
  X = Activation('relu')(X)

  X = Conv2D(f2, kernel_size = (3,3), strides =(1,1), padding = 'same', name ='res_'+str(stage)+'_identity_2_b', kernel_initializer= glorot_uniform(seed = 0))(X)
  X = BatchNormalization(axis =3, name = 'bn_'+str(stage)+'_identity_2_b')(X)
  X = Activation('relu')(X)

  X = Conv2D(f3, kernel_size = (1,1), strides =(1,1),name ='res_'+str(stage)+'_identity_2_c', kernel_initializer= glorot_uniform(seed = 0))(X)
  X = BatchNormalization(axis =3, name = 'bn_'+str(stage)+'_identity_2_c')(X)

  # ADD
  X = Add()([X,X_copy])
  X = Activation('relu')(X)

  return X

# %%
input_shape = (48, 48, 1)

# Input tensor shape
X_input = Input(input_shape)

# Zero-padding
X = ZeroPadding2D((3, 3))(X_input)

# 1 - stage
X = Conv2D(64, (7, 7), strides= (2, 2), name = 'conv1', kernel_initializer= glorot_uniform(seed = 0))(X)
X = BatchNormalization(axis =3, name = 'bn_conv1')(X)
X = Activation('relu')(X)
X = MaxPooling2D((3, 3), strides= (2, 2))(X)

# 2 - stage
X = res_block(X, filter= [64, 64, 256], stage= 2)

# 3 - stage
X = res_block(X, filter= [128, 128, 512], stage= 3)

# 4 - stage
# X = res_block(X, filter= [256, 256, 1024], stage= 4)

# Average Pooling
X = AveragePooling2D((2, 2), name = 'Averagea_Pooling')(X)

# Final layer
X = Flatten()(X)
X = Dense(5, activation = 'softmax', name = 'Dense_final', kernel_initializer= glorot_uniform(seed=0))(X)

model_emotion = Model( inputs= X_input, outputs = X, name = 'Resnet18')

model_emotion.summary()
# Out:
# Model: "Resnet18"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 48, 48, 1)]          0         []
#
#  zero_padding2d (ZeroPaddin  (None, 54, 54, 1)            0         ['input_1[0][0]']
#  g2D)
#
#  conv1 (Conv2D)              (None, 24, 24, 64)           3200      ['zero_padding2d[0][0]']
#
#  bn_conv1 (BatchNormalizati  (None, 24, 24, 64)           256       ['conv1[0][0]']
#  on)
#
#  activation (Activation)     (None, 24, 24, 64)           0         ['bn_conv1[0][0]']
#
#  max_pooling2d (MaxPooling2  (None, 11, 11, 64)           0         ['activation[0][0]']
#  D)
#
#  res_2_conv_a (Conv2D)       (None, 11, 11, 64)           4160      ['max_pooling2d[0][0]']
#
#  max_pooling2d_1 (MaxPoolin  (None, 5, 5, 64)             0         ['res_2_conv_a[0][0]']
#  g2D)
#
#  bn_2_conv_a (BatchNormaliz  (None, 5, 5, 64)             256       ['max_pooling2d_1[0][0]']
#  ation)
#
#  activation_1 (Activation)   (None, 5, 5, 64)             0         ['bn_2_conv_a[0][0]']
#
#  res_2_conv_b (Conv2D)       (None, 5, 5, 64)             36928     ['activation_1[0][0]']
#
#  bn_2_conv_b (BatchNormaliz  (None, 5, 5, 64)             256       ['res_2_conv_b[0][0]']
#  ation)
#
#  activation_2 (Activation)   (None, 5, 5, 64)             0         ['bn_2_conv_b[0][0]']
#
#  res_2_conv_copy (Conv2D)    (None, 11, 11, 256)          16640     ['max_pooling2d[0][0]']
#
#  res_2_conv_c (Conv2D)       (None, 5, 5, 256)            16640     ['activation_2[0][0]']
#
#  max_pooling2d_2 (MaxPoolin  (None, 5, 5, 256)            0         ['res_2_conv_copy[0][0]']
#  g2D)
#
#  bn_2_conv_c (BatchNormaliz  (None, 5, 5, 256)            1024      ['res_2_conv_c[0][0]']
#  ation)
#
#  bn_2_conv_copy (BatchNorma  (None, 5, 5, 256)            1024      ['max_pooling2d_2[0][0]']
#  lization)
#
#  add (Add)                   (None, 5, 5, 256)            0         ['bn_2_conv_c[0][0]',
#                                                                      'bn_2_conv_copy[0][0]']
#
#  activation_3 (Activation)   (None, 5, 5, 256)            0         ['add[0][0]']
#
#  res_2_identity_1_a (Conv2D  (None, 5, 5, 64)             16448     ['activation_3[0][0]']
#  )
#
#  bn_2_identity_1_a (BatchNo  (None, 5, 5, 64)             256       ['res_2_identity_1_a[0][0]']
#  rmalization)
#
#  activation_4 (Activation)   (None, 5, 5, 64)             0         ['bn_2_identity_1_a[0][0]']
#
#  res_2_identity_1_b (Conv2D  (None, 5, 5, 64)             36928     ['activation_4[0][0]']
#  )
#
#  bn_2_identity_1_b (BatchNo  (None, 5, 5, 64)             256       ['res_2_identity_1_b[0][0]']
#  rmalization)
#
#  activation_5 (Activation)   (None, 5, 5, 64)             0         ['bn_2_identity_1_b[0][0]']
#
#  res_2_identity_1_c (Conv2D  (None, 5, 5, 256)            16640     ['activation_5[0][0]']
#  )
#
#  bn_2_identity_1_c (BatchNo  (None, 5, 5, 256)            1024      ['res_2_identity_1_c[0][0]']
#  rmalization)
#
#  add_1 (Add)                 (None, 5, 5, 256)            0         ['bn_2_identity_1_c[0][0]',
#                                                                      'activation_3[0][0]']
#
#  activation_6 (Activation)   (None, 5, 5, 256)            0         ['add_1[0][0]']
#
#  res_2_identity_2_a (Conv2D  (None, 5, 5, 64)             16448     ['activation_6[0][0]']
#  )
#
#  bn_2_identity_2_a (BatchNo  (None, 5, 5, 64)             256       ['res_2_identity_2_a[0][0]']
#  rmalization)
#
#  activation_7 (Activation)   (None, 5, 5, 64)             0         ['bn_2_identity_2_a[0][0]']
#
#  res_2_identity_2_b (Conv2D  (None, 5, 5, 64)             36928     ['activation_7[0][0]']
#  )
#
#  bn_2_identity_2_b (BatchNo  (None, 5, 5, 64)             256       ['res_2_identity_2_b[0][0]']
#  rmalization)
#
#  activation_8 (Activation)   (None, 5, 5, 64)             0         ['bn_2_identity_2_b[0][0]']
#
#  res_2_identity_2_c (Conv2D  (None, 5, 5, 256)            16640     ['activation_8[0][0]']
#  )
#
#  bn_2_identity_2_c (BatchNo  (None, 5, 5, 256)            1024      ['res_2_identity_2_c[0][0]']
#  rmalization)
#
#  add_2 (Add)                 (None, 5, 5, 256)            0         ['bn_2_identity_2_c[0][0]',
#                                                                      'activation_6[0][0]']
#
#  activation_9 (Activation)   (None, 5, 5, 256)            0         ['add_2[0][0]']
#
#  res_3_conv_a (Conv2D)       (None, 5, 5, 128)            32896     ['activation_9[0][0]']
#
#  max_pooling2d_3 (MaxPoolin  (None, 2, 2, 128)            0         ['res_3_conv_a[0][0]']
#  g2D)
#
#  bn_3_conv_a (BatchNormaliz  (None, 2, 2, 128)            512       ['max_pooling2d_3[0][0]']
#  ation)
#
#  activation_10 (Activation)  (None, 2, 2, 128)            0         ['bn_3_conv_a[0][0]']
#
#  res_3_conv_b (Conv2D)       (None, 2, 2, 128)            147584    ['activation_10[0][0]']
#
#  bn_3_conv_b (BatchNormaliz  (None, 2, 2, 128)            512       ['res_3_conv_b[0][0]']
#  ation)
#
#  activation_11 (Activation)  (None, 2, 2, 128)            0         ['bn_3_conv_b[0][0]']
#
#  res_3_conv_copy (Conv2D)    (None, 5, 5, 512)            131584    ['activation_9[0][0]']
#
#  res_3_conv_c (Conv2D)       (None, 2, 2, 512)            66048     ['activation_11[0][0]']
#
#  max_pooling2d_4 (MaxPoolin  (None, 2, 2, 512)            0         ['res_3_conv_copy[0][0]']
#  g2D)
#
#  bn_3_conv_c (BatchNormaliz  (None, 2, 2, 512)            2048      ['res_3_conv_c[0][0]']
#  ation)
#
#  bn_3_conv_copy (BatchNorma  (None, 2, 2, 512)            2048      ['max_pooling2d_4[0][0]']
#  lization)
#
#  add_3 (Add)                 (None, 2, 2, 512)            0         ['bn_3_conv_c[0][0]',
#                                                                      'bn_3_conv_copy[0][0]']
#
#  activation_12 (Activation)  (None, 2, 2, 512)            0         ['add_3[0][0]']
#
#  res_3_identity_1_a (Conv2D  (None, 2, 2, 128)            65664     ['activation_12[0][0]']
#  )
#
#  bn_3_identity_1_a (BatchNo  (None, 2, 2, 128)            512       ['res_3_identity_1_a[0][0]']
#  rmalization)
#
#  activation_13 (Activation)  (None, 2, 2, 128)            0         ['bn_3_identity_1_a[0][0]']
#
#  res_3_identity_1_b (Conv2D  (None, 2, 2, 128)            147584    ['activation_13[0][0]']
#  )
#
#  bn_3_identity_1_b (BatchNo  (None, 2, 2, 128)            512       ['res_3_identity_1_b[0][0]']
#  rmalization)
#
#  activation_14 (Activation)  (None, 2, 2, 128)            0         ['bn_3_identity_1_b[0][0]']
#
#  res_3_identity_1_c (Conv2D  (None, 2, 2, 512)            66048     ['activation_14[0][0]']
#  )
#
#  bn_3_identity_1_c (BatchNo  (None, 2, 2, 512)            2048      ['res_3_identity_1_c[0][0]']
#  rmalization)
#
#  add_4 (Add)                 (None, 2, 2, 512)            0         ['bn_3_identity_1_c[0][0]',
#                                                                      'activation_12[0][0]']
#
#  activation_15 (Activation)  (None, 2, 2, 512)            0         ['add_4[0][0]']
#
#  res_3_identity_2_a (Conv2D  (None, 2, 2, 128)            65664     ['activation_15[0][0]']
#  )
#
#  bn_3_identity_2_a (BatchNo  (None, 2, 2, 128)            512       ['res_3_identity_2_a[0][0]']
#  rmalization)
#
#  activation_16 (Activation)  (None, 2, 2, 128)            0         ['bn_3_identity_2_a[0][0]']
#
#  res_3_identity_2_b (Conv2D  (None, 2, 2, 128)            147584    ['activation_16[0][0]']
#  )
#
#  bn_3_identity_2_b (BatchNo  (None, 2, 2, 128)            512       ['res_3_identity_2_b[0][0]']
#  rmalization)
#
#  activation_17 (Activation)  (None, 2, 2, 128)            0         ['bn_3_identity_2_b[0][0]']
#
#  res_3_identity_2_c (Conv2D  (None, 2, 2, 512)            66048     ['activation_17[0][0]']
#  )
#
#  bn_3_identity_2_c (BatchNo  (None, 2, 2, 512)            2048      ['res_3_identity_2_c[0][0]']
#  rmalization)
#
#  add_5 (Add)                 (None, 2, 2, 512)            0         ['bn_3_identity_2_c[0][0]',
#                                                                      'activation_15[0][0]']
#
#  activation_18 (Activation)  (None, 2, 2, 512)            0         ['add_5[0][0]']
#
#  Averagea_Pooling (AverageP  (None, 1, 1, 512)            0         ['activation_18[0][0]']
#  ooling2D)
#
#  flatten (Flatten)           (None, 512)                  0         ['Averagea_Pooling[0][0]']
#
#  Dense_final (Dense)         (None, 5)                    2565      ['flatten[0][0]']
#
# ==================================================================================================
# Total params: 1174021 (4.48 MB)
# Trainable params: 1165445 (4.45 MB)
# Non-trainable params: 8576 (33.50 KB)
# __________________________________________________________________________________________________

# %%
# train the network
model_emotion.compile(optimizer = "Adam", loss = "categorical_crossentropy", metrics = ["accuracy"])

# %%
# Recall that the first facial key points model was saved as follows: FacialKeyPoints_weights.hdf5 and FacialKeyPoints-model.json

# using early stopping to exit training if validation loss is not decreasing even after certain epochs (patience)
earlystopping = EarlyStopping(monitor = 'val_loss', mode = 'min', verbose = 1, patience = 30)

# save the best model with lower validation loss
checkpointer = ModelCheckpoint(filepath = "FacialExpression_weights.hdf5", verbose = 1, save_best_only=True)

# %%
history = model_emotion.fit(train_datagen.flow(X_train, y_train, batch_size=64),
	validation_data=(X_val, y_val), steps_per_epoch=len(X_train) // 64,
	epochs= 50, callbacks=[checkpointer, earlystopping])
# Out:
# Epoch 1/50
# 345/345 [==============================] - ETA: 0s - loss: 0.7756 - accuracy: 0.6958
# Epoch 1: val_loss did not improve from 0.75743
# 345/345 [==============================] - 28s 43ms/step - loss: 0.7756 - accuracy: 0.6958 - val_loss: 0.7961 - val_accuracy: 0.6808
# Epoch 2/50
# 345/345 [==============================] - ETA: 0s - loss: 0.7666 - accuracy: 0.7040
# Epoch 2: val_loss did not improve from 0.75743
# 345/345 [==============================] - 15s 43ms/step - loss: 0.7666 - accuracy: 0.7040 - val_loss: 0.7711 - val_accuracy: 0.6849
# Epoch 3/50
# 345/345 [==============================] - ETA: 0s - loss: 0.7559 - accuracy: 0.7060
# Epoch 3: val_loss did not improve from 0.75743
# 345/345 [==============================] - 15s 42ms/step - loss: 0.7559 - accuracy: 0.7060 - val_loss: 0.8133 - val_accuracy: 0.6792
# Epoch 4/50
# 345/345 [==============================] - ETA: 0s - loss: 0.7469 - accuracy: 0.7079
# Epoch 4: val_loss did not improve from 0.75743
# 345/345 [==============================] - 15s 42ms/step - loss: 0.7469 - accuracy: 0.7079 - val_loss: 0.8413 - val_accuracy: 0.6694
# Epoch 5/50
# 344/345 [============================>.] - ETA: 0s - loss: 0.7513 - accuracy: 0.7078
# Epoch 5: val_loss did not improve from 0.75743
# 345/345 [==============================] - 14s 42ms/step - loss: 0.7512 - accuracy: 0.7075 - val_loss: 0.8519 - val_accuracy: 0.6759
# Epoch 6/50
# 345/345 [==============================] - ETA: 0s - loss: 0.7296 - accuracy: 0.7135
# Epoch 6: val_loss did not improve from 0.75743
# 345/345 [==============================] - 15s 44ms/step - loss: 0.7296 - accuracy: 0.7135 - val_loss: 0.7882 - val_accuracy: 0.6881
# Epoch 7/50
# 344/345 [============================>.] - ETA: 0s - loss: 0.7326 - accuracy: 0.7171
# Epoch 7: val_loss did not improve from 0.75743
# 345/345 [==============================] - 15s 45ms/step - loss: 0.7330 - accuracy: 0.7169 - val_loss: 0.8183 - val_accuracy: 0.6775
# Epoch 8/50
# 344/345 [============================>.] - ETA: 0s - loss: 0.7186 - accuracy: 0.7186
# Epoch 8: val_loss improved from 0.75743 to 0.73409, saving model to FacialExpression_weights.hdf5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 345/345 [==============================] - 15s 44ms/step - loss: 0.7194 - accuracy: 0.7184 - val_loss: 0.7341 - val_accuracy: 0.7125
# Epoch 9/50
# 344/345 [============================>.] - ETA: 0s - loss: 0.7177 - accuracy: 0.7231
# Epoch 9: val_loss did not improve from 0.73409
# 345/345 [==============================] - 14s 42ms/step - loss: 0.7170 - accuracy: 0.7233 - val_loss: 1.0511 - val_accuracy: 0.6034
# Epoch 10/50
# 345/345 [==============================] - ETA: 0s - loss: 0.7187 - accuracy: 0.7205
# Epoch 10: val_loss did not improve from 0.73409
# 345/345 [==============================] - 15s 42ms/step - loss: 0.7187 - accuracy: 0.7205 - val_loss: 0.8040 - val_accuracy: 0.6694
# Epoch 11/50
# 344/345 [============================>.] - ETA: 0s - loss: 0.7106 - accuracy: 0.7241
# Epoch 11: val_loss improved from 0.73409 to 0.73215, saving model to FacialExpression_weights.hdf5
# 345/345 [==============================] - 15s 44ms/step - loss: 0.7107 - accuracy: 0.7239 - val_loss: 0.7322 - val_accuracy: 0.7101
# Epoch 12/50
# 345/345 [==============================] - ETA: 0s - loss: 0.7048 - accuracy: 0.7258
# Epoch 12: val_loss did not improve from 0.73215
# 345/345 [==============================] - 14s 41ms/step - loss: 0.7048 - accuracy: 0.7258 - val_loss: 0.8412 - val_accuracy: 0.6612
# Epoch 13/50
# 344/345 [============================>.] - ETA: 0s - loss: 0.6903 - accuracy: 0.7336
# Epoch 13: val_loss did not improve from 0.73215
# 345/345 [==============================] - 14s 42ms/step - loss: 0.6905 - accuracy: 0.7335 - val_loss: 0.8032 - val_accuracy: 0.6824
# Epoch 14/50
# 345/345 [==============================] - ETA: 0s - loss: 0.6956 - accuracy: 0.7307
# Epoch 14: val_loss did not improve from 0.73215
# 345/345 [==============================] - 15s 43ms/step - loss: 0.6956 - accuracy: 0.7307 - val_loss: 0.7852 - val_accuracy: 0.6954
# Epoch 15/50
# 345/345 [==============================] - ETA: 0s - loss: 0.6883 - accuracy: 0.7322
# Epoch 15: val_loss improved from 0.73215 to 0.71594, saving model to FacialExpression_weights.hdf5
# 345/345 [==============================] - 15s 44ms/step - loss: 0.6883 - accuracy: 0.7322 - val_loss: 0.7159 - val_accuracy: 0.7288
# Epoch 16/50
# 344/345 [============================>.] - ETA: 0s - loss: 0.6818 - accuracy: 0.7383
# Epoch 16: val_loss did not improve from 0.71594
# 345/345 [==============================] - 15s 45ms/step - loss: 0.6817 - accuracy: 0.7382 - val_loss: 0.8524 - val_accuracy: 0.6604
# Epoch 17/50
# 345/345 [==============================] - ETA: 0s - loss: 0.6791 - accuracy: 0.7374
# Epoch 17: val_loss did not improve from 0.71594
# 345/345 [==============================] - 15s 43ms/step - loss: 0.6791 - accuracy: 0.7374 - val_loss: 0.7557 - val_accuracy: 0.7077
# Epoch 18/50
# 345/345 [==============================] - ETA: 0s - loss: 0.6710 - accuracy: 0.7412
# Epoch 18: val_loss did not improve from 0.71594
# 345/345 [==============================] - 15s 42ms/step - loss: 0.6710 - accuracy: 0.7412 - val_loss: 0.8321 - val_accuracy: 0.6751
# Epoch 19/50
# 345/345 [==============================] - ETA: 0s - loss: 0.6696 - accuracy: 0.7438
# Epoch 19: val_loss improved from 0.71594 to 0.68757, saving model to FacialExpression_weights.hdf5
# 345/345 [==============================] - 15s 43ms/step - loss: 0.6696 - accuracy: 0.7438 - val_loss: 0.6876 - val_accuracy: 0.7394
# Epoch 20/50
# 345/345 [==============================] - ETA: 0s - loss: 0.6718 - accuracy: 0.7409
# Epoch 20: val_loss did not improve from 0.68757
# 345/345 [==============================] - 14s 42ms/step - loss: 0.6718 - accuracy: 0.7409 - val_loss: 0.7173 - val_accuracy: 0.7264
# Epoch 21/50
# 345/345 [==============================] - ETA: 0s - loss: 0.6640 - accuracy: 0.7450
# Epoch 21: val_loss did not improve from 0.68757
# 345/345 [==============================] - 15s 42ms/step - loss: 0.6640 - accuracy: 0.7450 - val_loss: 0.7471 - val_accuracy: 0.7060
# Epoch 22/50
# 344/345 [============================>.] - ETA: 0s - loss: 0.6581 - accuracy: 0.7465
# Epoch 22: val_loss did not improve from 0.68757
# 345/345 [==============================] - 15s 43ms/step - loss: 0.6589 - accuracy: 0.7464 - val_loss: 0.8434 - val_accuracy: 0.6873
# Epoch 23/50
# 345/345 [==============================] - ETA: 0s - loss: 0.6524 - accuracy: 0.7507
# Epoch 23: val_loss did not improve from 0.68757
# 345/345 [==============================] - 15s 44ms/step - loss: 0.6524 - accuracy: 0.7507 - val_loss: 0.8216 - val_accuracy: 0.6710
# Epoch 24/50
# 345/345 [==============================] - ETA: 0s - loss: 0.6516 - accuracy: 0.7460
# Epoch 24: val_loss did not improve from 0.68757
# 345/345 [==============================] - 15s 43ms/step - loss: 0.6516 - accuracy: 0.7460 - val_loss: 0.7917 - val_accuracy: 0.6865
# Epoch 25/50
# 345/345 [==============================] - ETA: 0s - loss: 0.6434 - accuracy: 0.7534
# Epoch 25: val_loss did not improve from 0.68757
# 345/345 [==============================] - 16s 46ms/step - loss: 0.6434 - accuracy: 0.7534 - val_loss: 0.7583 - val_accuracy: 0.6914
# Epoch 26/50
# 344/345 [============================>.] - ETA: 0s - loss: 0.6430 - accuracy: 0.7536
# Epoch 26: val_loss did not improve from 0.68757
# 345/345 [==============================] - 15s 42ms/step - loss: 0.6435 - accuracy: 0.7535 - val_loss: 0.7421 - val_accuracy: 0.7142
# Epoch 27/50
# 345/345 [==============================] - ETA: 0s - loss: 0.6458 - accuracy: 0.7474
# Epoch 27: val_loss did not improve from 0.68757
# 345/345 [==============================] - 14s 42ms/step - loss: 0.6458 - accuracy: 0.7474 - val_loss: 0.8135 - val_accuracy: 0.6816
# Epoch 28/50
# 344/345 [============================>.] - ETA: 0s - loss: 0.6429 - accuracy: 0.7523
# Epoch 28: val_loss did not improve from 0.68757
# 345/345 [==============================] - 14s 42ms/step - loss: 0.6428 - accuracy: 0.7521 - val_loss: 0.9351 - val_accuracy: 0.6458
# Epoch 29/50
# 345/345 [==============================] - ETA: 0s - loss: 0.6311 - accuracy: 0.7565
# Epoch 29: val_loss improved from 0.68757 to 0.65911, saving model to FacialExpression_weights.hdf5
# 345/345 [==============================] - 15s 43ms/step - loss: 0.6311 - accuracy: 0.7565 - val_loss: 0.6591 - val_accuracy: 0.7362
# Epoch 30/50
# 345/345 [==============================] - ETA: 0s - loss: 0.6285 - accuracy: 0.7569
# Epoch 30: val_loss did not improve from 0.65911
# 345/345 [==============================] - 15s 42ms/step - loss: 0.6285 - accuracy: 0.7569 - val_loss: 0.7370 - val_accuracy: 0.7142
# Epoch 31/50
# 344/345 [============================>.] - ETA: 0s - loss: 0.6264 - accuracy: 0.7580
# Epoch 31: val_loss did not improve from 0.65911
# 345/345 [==============================] - 15s 43ms/step - loss: 0.6269 - accuracy: 0.7579 - val_loss: 0.7470 - val_accuracy: 0.6971
# Epoch 32/50
# 345/345 [==============================] - ETA: 0s - loss: 0.6183 - accuracy: 0.7625
# Epoch 32: val_loss did not improve from 0.65911
# 345/345 [==============================] - 14s 42ms/step - loss: 0.6183 - accuracy: 0.7625 - val_loss: 0.7020 - val_accuracy: 0.7345
# Epoch 33/50
# 344/345 [============================>.] - ETA: 0s - loss: 0.6228 - accuracy: 0.7610
# Epoch 33: val_loss did not improve from 0.65911
# 345/345 [==============================] - 15s 42ms/step - loss: 0.6226 - accuracy: 0.7610 - val_loss: 0.7098 - val_accuracy: 0.7215
# Epoch 34/50
# 344/345 [============================>.] - ETA: 0s - loss: 0.6209 - accuracy: 0.7617
# Epoch 34: val_loss did not improve from 0.65911
# 345/345 [==============================] - 14s 42ms/step - loss: 0.6211 - accuracy: 0.7616 - val_loss: 0.7582 - val_accuracy: 0.7166
# Epoch 35/50
# 345/345 [==============================] - ETA: 0s - loss: 0.6196 - accuracy: 0.7628
# Epoch 35: val_loss did not improve from 0.65911
# 345/345 [==============================] - 14s 42ms/step - loss: 0.6196 - accuracy: 0.7628 - val_loss: 0.7427 - val_accuracy: 0.7093
# Epoch 36/50
# 344/345 [============================>.] - ETA: 0s - loss: 0.6158 - accuracy: 0.7627
# Epoch 36: val_loss improved from 0.65911 to 0.63171, saving model to FacialExpression_weights.hdf5
# 345/345 [==============================] - 15s 43ms/step - loss: 0.6155 - accuracy: 0.7627 - val_loss: 0.6317 - val_accuracy: 0.7638
# Epoch 37/50
# 344/345 [============================>.] - ETA: 0s - loss: 0.6084 - accuracy: 0.7674
# Epoch 37: val_loss did not improve from 0.63171
# 345/345 [==============================] - 15s 43ms/step - loss: 0.6081 - accuracy: 0.7675 - val_loss: 0.8135 - val_accuracy: 0.6914
# Epoch 38/50
# 345/345 [==============================] - ETA: 0s - loss: 0.6023 - accuracy: 0.7708
# Epoch 38: val_loss did not improve from 0.63171
# 345/345 [==============================] - 14s 42ms/step - loss: 0.6023 - accuracy: 0.7708 - val_loss: 0.6427 - val_accuracy: 0.7573
# Epoch 39/50
# 345/345 [==============================] - ETA: 0s - loss: 0.6037 - accuracy: 0.7677
# Epoch 39: val_loss did not improve from 0.63171
# 345/345 [==============================] - 15s 44ms/step - loss: 0.6037 - accuracy: 0.7677 - val_loss: 0.7980 - val_accuracy: 0.6889
# Epoch 40/50
# 344/345 [============================>.] - ETA: 0s - loss: 0.5938 - accuracy: 0.7672
# Epoch 40: val_loss did not improve from 0.63171
# 345/345 [==============================] - 15s 42ms/step - loss: 0.5935 - accuracy: 0.7674 - val_loss: 0.7200 - val_accuracy: 0.7288
# Epoch 41/50
# 345/345 [==============================] - ETA: 0s - loss: 0.6031 - accuracy: 0.7693
# Epoch 41: val_loss did not improve from 0.63171
# 345/345 [==============================] - 15s 44ms/step - loss: 0.6031 - accuracy: 0.7693 - val_loss: 0.8123 - val_accuracy: 0.6963
# Epoch 42/50
# 344/345 [============================>.] - ETA: 0s - loss: 0.5987 - accuracy: 0.7709
# Epoch 42: val_loss did not improve from 0.63171
# 345/345 [==============================] - 15s 42ms/step - loss: 0.5986 - accuracy: 0.7709 - val_loss: 0.6779 - val_accuracy: 0.7337
# Epoch 43/50
# 344/345 [============================>.] - ETA: 0s - loss: 0.5901 - accuracy: 0.7729
# Epoch 43: val_loss did not improve from 0.63171
# 345/345 [==============================] - 15s 42ms/step - loss: 0.5896 - accuracy: 0.7732 - val_loss: 0.6992 - val_accuracy: 0.7345
# Epoch 44/50
# 344/345 [============================>.] - ETA: 0s - loss: 0.5901 - accuracy: 0.7732
# Epoch 44: val_loss did not improve from 0.63171
# 345/345 [==============================] - 15s 43ms/step - loss: 0.5899 - accuracy: 0.7733 - val_loss: 0.6600 - val_accuracy: 0.7427
# Epoch 45/50
# 344/345 [============================>.] - ETA: 0s - loss: 0.5884 - accuracy: 0.7731
# Epoch 45: val_loss did not improve from 0.63171
# 345/345 [==============================] - 15s 42ms/step - loss: 0.5881 - accuracy: 0.7734 - val_loss: 0.7564 - val_accuracy: 0.7020
# Epoch 46/50
# 345/345 [==============================] - ETA: 0s - loss: 0.5837 - accuracy: 0.7762
# Epoch 46: val_loss did not improve from 0.63171
# 345/345 [==============================] - 15s 43ms/step - loss: 0.5837 - accuracy: 0.7762 - val_loss: 0.6462 - val_accuracy: 0.7541
# Epoch 47/50
# 345/345 [==============================] - ETA: 0s - loss: 0.5818 - accuracy: 0.7770
# Epoch 47: val_loss did not improve from 0.63171
# 345/345 [==============================] - 15s 43ms/step - loss: 0.5818 - accuracy: 0.7770 - val_loss: 0.6431 - val_accuracy: 0.7565
# Epoch 48/50
# 345/345 [==============================] - ETA: 0s - loss: 0.5833 - accuracy: 0.7749
# Epoch 48: val_loss did not improve from 0.63171
# 345/345 [==============================] - 15s 44ms/step - loss: 0.5833 - accuracy: 0.7749 - val_loss: 0.7558 - val_accuracy: 0.7182
# Epoch 49/50
# 345/345 [==============================] - ETA: 0s - loss: 0.5760 - accuracy: 0.7788
# Epoch 49: val_loss did not improve from 0.63171
# 345/345 [==============================] - 15s 43ms/step - loss: 0.5760 - accuracy: 0.7788 - val_loss: 0.8663 - val_accuracy: 0.7223
# Epoch 50/50
# 344/345 [============================>.] - ETA: 0s - loss: 0.5676 - accuracy: 0.7854
# Epoch 50: val_loss did not improve from 0.63171
# 345/345 [==============================] - 15s 43ms/step - loss: 0.5675 - accuracy: 0.7853 - val_loss: 0.6636 - val_accuracy: 0.7533

# %%
# saving the model architecture to json file for future use

model_json = model_emotion.to_json()
with open("Emotion-model.json","w") as json_file:
  json_file.write(model_json)

# %% [markdown]
# MINI CHALLENGE #5:
# - Experiment with various batch size, patience, optimizers, and network architecture to improve network performance (Take home)

# %% [markdown]
# # STEP 6: #
#  ASSESS THE PERFORMANCE OF TRAINED FACIAL EXPRESSION CLASSIFIER MODEL

# %%
with open('Emotion-model.json', 'r') as json_file:
    json_savedModel= json_file.read()

# load the model architecture
model_emotion = tf.keras.models.model_from_json(json_savedModel)
model_emotion.load_weights('FacialExpression_weights.hdf5')
model_emotion.compile(optimizer = "Adam", loss = "categorical_crossentropy", metrics = ["accuracy"])

# %%
score = model_emotion.evaluate(X_Test, y_Test)
print('Test Accuracy: {}'.format(score[1]))
# Out:
# 39/39 [==============================] - 1s 6ms/step - loss: 0.7203 - accuracy: 0.7209
# Test Accuracy: 0.7209113240242004

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

# %%
epochs = range(len(accuracy))

plt.plot(epochs, accuracy, 'bo', label='Training Accuracy')
plt.plot(epochs, val_accuracy, 'b', label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()

# %%
plt.plot(epochs, loss, 'ro', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and Validation loss')
plt.legend()

# %%
# predicted_classes = model.predict_classes(X_test)
predicted_classes = np.argmax(model_emotion.predict(X_Test), axis=-1)
y_true = np.argmax(y_Test, axis=-1)
# Out:
# 39/39 [==============================] - 1s 4ms/step

# %%
y_true.shape
# Out:
# (1229,)

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_true, predicted_classes)
plt.figure(figsize = (10, 10))
sns.heatmap(cm, annot = True, cbar = False)
# Out:
# <Axes: >

# %% [markdown]
# - Print out a grid of 25 images along with their predicted/true label
# - Print out the classification report and analyze precision and recall

# %%
L = 5
W = 5

fig, axes = plt.subplots(L, W, figsize = (24, 24))
axes = axes.ravel()

for i in np.arange(0, L*W):
    axes[i].imshow(X_Test[i].reshape(48,48), cmap = 'gray')
    axes[i].set_title('Prediction = {}\n True = {}'.format(label_to_text[predicted_classes[i]], label_to_text[y_true[i]]))
    axes[i].axis('off')

plt.subplots_adjust(wspace = 1)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_true, predicted_classes))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.44      0.50      0.46       224
#            1       0.00      0.00      0.00        29
#            2       0.66      0.55      0.60       317
#            3       0.78      0.86      0.82       479
#            4       0.76      0.78      0.77       180
#
#     accuracy                           0.68      1229
#    macro avg       0.53      0.54      0.53      1229
# weighted avg       0.67      0.68      0.67      1229

# %% [markdown]
# #FURTHER EXPLORATIONS:#

# %% [markdown]
# - Visualize the first image in the dataframe and make sure that the image is not distorted by reshaping operation

# %%
plt.imshow(emotion_df['pixels'][0].squeeze(), cmap = 'gray')

# %% [markdown]
# - Plot barplot showing how many samples are present per emotion

# %%
plt.figure(figsize = (10, 10))
sns.barplot(x = emotion_df.emotion.value_counts().index, y = emotion_df.emotion.value_counts() )
plt.title('Number of images per emotion')
# Out:
# /Users/deathslayer/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/deathslayer/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /Users/deathslayer/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# Text(0.5, 1.0, 'Number of images per emotion')

# %% [markdown]
# https://keras.io/api/preprocessing/image/
